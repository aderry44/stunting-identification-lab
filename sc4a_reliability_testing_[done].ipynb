# %% [markdown]
# #1\. Initialization

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab

# %%
SEED = 123
EPOCHS = 20

# %%
import os
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"  # must be before torch import

# %%
import math, random, hashlib, copy
import pandas as pd
import numpy as np

from pathlib import Path
from typing  import Tuple, List
from PIL     import Image, ImageEnhance

from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms.functional as TF

from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

from sklearn.metrics import fbeta_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
print("Device:", torch.cuda.get_device_name(0))
print("CUDA version:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())
print("PyTorch version:", torch.__version__)
# Out:
# Device: Tesla T4
# CUDA version: 12.8
# cuDNN version: 91900
# PyTorch version: 2.11.0+cu128

# %%
sc4a_loss_function_result = []
sc4a_reliability_result   = []

# %% [markdown]
# #2\. Data Loading

# %%
val_sc4a_df   = pd.read_excel("/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/train-val-test/sc4a/val_sc4a.xlsx")
test_sc4a_df  = pd.read_excel("/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/train-val-test/sc4a/test_sc4a.xlsx")

# %% [markdown]
# #3\. Pre-processing Set

# %%
# Transformation

IMAGE_SIZE = 224

imagenet_norm = transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])

eval_tfms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.ToTensor(),
    imagenet_norm,
])

# %%
# Dataset Loader

BATCH_SIZE = 32
NUM_WORKERS = 2

class FaceDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        sample = self.dataframe.iloc[idx]
        image  = Image.open(sample["path"]).convert("RGB")
        image  = self.transform(image) if self.transform else transforms.ToTensor()(image)
        label  = int(sample["label"])
        return {
            "image": image,
            "label": torch.tensor(label, dtype=torch.long),
            "child_id": str(sample["child_id"]),
            "path": str(sample["path"]),
        }

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

def make_loader(dataframe, transform, shuffle):
    ds = FaceDataset(dataframe, transform=transform)
    g  = torch.Generator()
    g.manual_seed(SEED)
    return DataLoader(
        ds,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        generator=g,
        worker_init_fn=seed_worker,  # ← ADD THIS
    )

# %% [markdown]
# #4\. Sc.4.a. EfficientNet-B0 with SGD

# %%
# Prediction: Function

def collect_predictions(model, loader):
    model.eval()
    rows = []
    with torch.no_grad():
        for batch in loader:
            xb = batch["image"].to(device, non_blocking=True)
            yb = batch["label"].cpu().numpy().astype(int)
            logits = model(xb)
            probs  = torch.softmax(logits, dim=1).detach().cpu().numpy()
            logits_np = logits.detach().cpu().numpy()

            for i in range(len(yb)):
                rows.append({
                    "child_id": batch["child_id"][i],
                    "path": batch["path"][i],
                    "label": int(yb[i]),
                    "logit0": float(logits_np[i, 0]),
                    "logit1": float(logits_np[i, 1]),
                    "prob0": float(probs[i, 0]),
                    "prob1": float(probs[i, 1])
                })
    return pd.DataFrame(rows)

# %%
#Evaluation Function

def safe_div(num, den):
    return float(num) / float(den) if den else 0.0

def metric_bundle(y_true, prob1, threshold):
    y_true = np.asarray(y_true).astype(int)
    prob1 = np.asarray(prob1).astype(float)
    y_pred = (prob1 >= threshold).astype(int)

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

    accuracy = safe_div(tn + tp, len(y_true))
    precision = safe_div(tp, tp + fp)
    sensitivity = safe_div(tp, tp + fn)   # recall for stunting
    specificity = safe_div(tn, tn + fp)
    f1 = safe_div(2 * precision * sensitivity, precision + sensitivity)
    beta2 = 2.0
    f2 = safe_div((1 + beta2**2) * precision * sensitivity, (beta2**2) * precision + sensitivity)
    bal_acc = 0.5 * (sensitivity + specificity)

    return {
        "accuracy": accuracy,
        "precision": precision,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "f1": f1,
        "f2": f2,
        "balanced_accuracy": bal_acc,
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp),
    }

# %%
# Bootstrap Resample

def bootstrap_subject_ci(subject_df, prob_col, threshold, n_boot=2000, seed=123):
    rng  = np.random.default_rng(seed)
    base = subject_df[["child_id", "label", prob_col]].copy().reset_index(drop=True)
    n    = len(base)

    metrics = {
        "accuracy": [], "precision": [], "sensitivity": [],
        "specificity": [], "f1": [], "f2": [], "balanced_accuracy": []
    }

    for _ in range(n_boot):
        idx    = rng.integers(0, n, size=n)
        sample = base.iloc[idx]
        m      = metric_bundle(sample["label"].values, sample[prob_col].values, threshold)
        for k in metrics:
            metrics[k].append(m[k])

    ci = {}
    for k, vals in metrics.items():
        ci[f"{k}_mean"]     = float(np.round(np.mean(vals)*100, 2))
        ci[f"{k}_std. dev"] = float(np.round(np.std(vals)*100, 2))
        ci[f"{k}_ci_low"]   = float(np.round(np.percentile(vals, 2.5)*100, 2))
        ci[f"{k}_ci_high"]  = float(np.round(np.percentile(vals, 97.5)*100, 2))
    return ci

# %%
def threshold_sweep(subject_df, prob_col, thresholds, objective="f2"):
    rows = []
    for thr in thresholds:
        m = metric_bundle(subject_df["label"].values, subject_df[prob_col].values, threshold=float(thr))
        rows.append({"threshold": float(thr), **m})

    table = pd.DataFrame(rows).sort_values(["threshold"]).reset_index(drop=True)
    best  = table.sort_values(
        by=[objective, "sensitivity", "specificity"],
        ascending=[False, False, False]
    ).iloc[0]
    return table, float(best["threshold"])

# %%
def fit_temperature(logits_np, labels_np, max_iter=50):
    logits_t = torch.tensor(logits_np, dtype=torch.float32)
    labels_t = torch.tensor(labels_np, dtype=torch.long)

    log_temp = nn.Parameter(torch.zeros(()))  # T = exp(log_temp), starts at 1.0
    optimizer = torch.optim.LBFGS([log_temp], lr=0.1, max_iter=max_iter, line_search_fn="strong_wolfe")

    def closure():
        optimizer.zero_grad()
        temp = torch.exp(log_temp).clamp(1e-3, 100.0)
        loss = F.cross_entropy(logits_t / temp, labels_t)
        loss.backward()
        return loss

    optimizer.step(closure)
    return float(torch.exp(log_temp).detach().cpu().item())

def apply_temperature(pred_df, temperature):
    logits   = pred_df[["logit0", "logit1"]].to_numpy(dtype=np.float32)
    logits_t = torch.tensor(logits, dtype=torch.float32)
    probs    = torch.softmax(logits_t / float(temperature), dim=1)[:, 1].numpy()
    out = pred_df.copy()
    out["prob1_cal"] = probs
    return out

# %%
# Model - pre-trained EfficientNet B0

def create_model(num_classes=2):
    weights = EfficientNet_B0_Weights.DEFAULT
    model   = efficientnet_b0(weights=weights)
    in_features = model.classifier[-1].in_features
    model.classifier[-1] = nn.Linear(in_features, num_classes)
    return model

# %% [markdown]
# ## 4\.1\. CE Loss Function

# %% [markdown]
# ### 4\.1\.1\. Model Initialization

# %%
# Model Initialization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Random Configuration
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = create_model(num_classes=2).to(device)
# Out:
# Device: cuda
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 114MB/s]

# %% [markdown]
# ### 4\.1\.2\. Data Loader

# %%
# Load Dataset
dl_val_sc4a   = make_loader(val_sc4a_df, eval_tfms, shuffle=False)
dl_test_sc4a  = make_loader(test_sc4a_df, eval_tfms, shuffle=False)

print(f"\nval={len(val_sc4a_df)} | test={len(test_sc4a_df)}")
# Out:
# val=19 | test=19

# %% [markdown]
# ### 4\.1\.3\. Model Evaluation

# %%
# Prediction on validation and test data
base = "/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/model/"
BEST_PATH = base + "best_model_efficientnet_b0_sc4a_sgd_CE.pth"

model.load_state_dict(torch.load(BEST_PATH, map_location=device))

val_predict   = collect_predictions(model, dl_val_sc4a)
test_predict  = collect_predictions(model, dl_test_sc4a)

# %% [markdown]
# ### 4\.1\.4\. Validation Data Performance

# %%
# Evaluation for Validation data
print('validation evaluation:')
result = metric_bundle(val_predict.label, val_predict.prob1, threshold=0.5)
result
# Out:
# validation evaluation:
# {'accuracy': 0.47368421052631576,
#  'precision': 0.25,
#  'sensitivity': 0.125,
#  'specificity': 0.7272727272727273,
#  'f1': 0.16666666666666666,
#  'f2': 0.1388888888888889,
#  'balanced_accuracy': 0.42613636363636365,
#  'TN': 8,
#  'FP': 3,
#  'FN': 7,
#  'TP': 1}

# %%
sc4a_loss_function_result.append([
     "sc4a-efficientnet-b0-sgd",
     "sc4a", "efficientnet-b0", "sgd", "CE",
     "validation",
     result["accuracy"],
     result["precision"],
     result["sensitivity"],
     result["specificity"],
     result["f1"],
     result["f2"],
     result["TN"],
     result["FP"],
     result["FN"],
     result["TP"],
])

# %% [markdown]
# ### 4\.1\.5\. Test Data Performance

# %%
# Evaluation for Test data
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=0.5)
result
# Out:
# test evaluation:
# {'accuracy': 0.5263157894736842,
#  'precision': 0.4,
#  'sensitivity': 0.25,
#  'specificity': 0.7272727272727273,
#  'f1': 0.3076923076923077,
#  'f2': 0.27027027027027023,
#  'balanced_accuracy': 0.48863636363636365,
#  'TN': 8,
#  'FP': 3,
#  'FN': 6,
#  'TP': 2}

# %%
sc4a_loss_function_result.append([
     "sc4a-efficientnet-b0-sgd",
     "sc4a", "efficientnet-b0", "sgd", "CE",
     "test",
     result["accuracy"],
     result["precision"],
     result["sensitivity"],
     result["specificity"],
     result["f1"],
     result["f2"],
     result["TN"],
     result["FP"],
     result["FN"],
     result["TP"],
])

# %% [markdown]
# ### 4\.1\.6\. Static Threshold

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=0.5, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 52.28,
#  'accuracy_std. dev': 11.49,
#  'accuracy_ci_low': 31.58,
#  'accuracy_ci_high': 73.68,
#  'precision_mean': 39.46,
#  'precision_std. dev': 24.38,
#  'precision_ci_low': 0.0,
#  'precision_ci_high': 100.0,
#  'sensitivity_mean': 24.55,
#  'sensitivity_std. dev': 15.65,
#  'sensitivity_ci_low': 0.0,
#  'sensitivity_ci_high': 57.14,
#  'specificity_mean': 72.6,
#  'specificity_std. dev': 13.82,
#  'specificity_ci_low': 42.86,
#  'specificity_ci_high': 100.0,
#  'f1_mean': 28.71,
#  'f1_std. dev': 16.65,
#  'f1_ci_low': 0.0,
#  'f1_ci_high': 58.85,
#  'f2_mean': 25.84,
#  'f2_std. dev': 15.69,
#  'f2_ci_low': 0.0,
#  'f2_ci_high': 57.14,
#  'balanced_accuracy_mean': 48.57,
#  'balanced_accuracy_std. dev': 10.6,
#  'balanced_accuracy_ci_low': 29.16,
#  'balanced_accuracy_ci_high': 69.29}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "CE", "0.5", 0.5,
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.1\.7\. Tuned Threshold

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

raw_curve, raw_thr = threshold_sweep(val_predict, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID,
                                     objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {raw_thr:0.4f}")
display(raw_curve[:5])
# Out:
# Best Threshold on Validation: 0.2300
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
# Evaluation Example
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=raw_thr)
display(raw_thr)
display(result)
# Out:
# test evaluation:
# 0.23
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=raw_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "CE", "tuned", np.round(raw_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.1\.8\. Calibrated Tuned Threshold

# %%
# Temperature scaling on validation logits -> calibrated probs
temperature = fit_temperature(
    val_predict[["logit0", "logit1"]].to_numpy(dtype=np.float32),
    val_predict["label"].to_numpy(dtype=np.int64),
    max_iter=50,
    )

print('temperature:', temperature)

val_pred_cal = apply_temperature(val_predict, temperature)
val_pred_cal.head(5)
# Out:
# temperature: 104.21685791015625
#   child_id                                               path  label  \
# 0        4  /content/drive/MyDrive/Stunted Children Identi...      1
# 1       13  /content/drive/MyDrive/Stunted Children Identi...      0
# 2       24  /content/drive/MyDrive/Stunted Children Identi...      0
# 3       28  /content/drive/MyDrive/Stunted Children Identi...      0
# 4       37  /content/drive/MyDrive/Stunted Children Identi...      0
#
#      logit0    logit1     prob0     prob1  prob1_cal
# 0  0.359255 -0.285560  0.655841  0.344159   0.498453
# 1  0.541295 -0.677641  0.771876  0.228124   0.497076
# 2  0.323749 -0.097959  0.603892  0.396108   0.498988
# 3  0.240506  0.042931  0.549234  0.450766   0.499526
# 4  0.098144 -0.218859  0.578594  0.421406   0.499240

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

cal_curve, cal_thr = threshold_sweep(val_pred_cal, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID, objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {cal_thr:0.4f}")
display(cal_curve[:5])
# Out:
# Best Threshold on Validation: 0.2300
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
print('test evaluation:')
# Evaluation Example
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=cal_thr)
display(result)
# Out:
# test evaluation:
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=cal_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "CE", "cal. tuned", np.round(cal_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ## 4\.2\. Class-Weighted CE Loss Function

# %% [markdown]
# ### 4\.2\.1\. Model Initialization

# %%
# Model Initialization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Random Configuration
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = create_model(num_classes=2).to(device)
# Out:
# Device: cuda

# %% [markdown]
# ### 4\.2\.2\. Data Loader

# %%
# Load Dataset
dl_val_sc4a   = make_loader(val_sc4a_df, eval_tfms, shuffle=False)
dl_test_sc4a  = make_loader(test_sc4a_df, eval_tfms, shuffle=False)

print(f"\nval={len(val_sc4a_df)} | test={len(test_sc4a_df)}")
# Out:
# val=19 | test=19

# %% [markdown]
# ### 4\.2\.3\. Model Evaluation

# %%
# Prediction on validation and test data
base = "/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/model/"
BEST_PATH = base + "best_model_efficientnet_b0_sc4a_sgd_weighted_CE.pth"

model.load_state_dict(torch.load(BEST_PATH, map_location=device))

val_predict   = collect_predictions(model, dl_val_sc4a)
test_predict  = collect_predictions(model, dl_test_sc4a)

# %% [markdown]
# ### 4\.2\.4\. Validation Data Performance

# %%
# Evaluation for Validation data
print('validation evaluation:')
result = metric_bundle(val_predict.label, val_predict.prob1, threshold=0.5)
result
# Out:
# validation evaluation:
# {'accuracy': 0.47368421052631576,
#  'precision': 0.3333333333333333,
#  'sensitivity': 0.25,
#  'specificity': 0.6363636363636364,
#  'f1': 0.28571428571428575,
#  'f2': 0.2631578947368421,
#  'balanced_accuracy': 0.4431818181818182,
#  'TN': 7,
#  'FP': 4,
#  'FN': 6,
#  'TP': 2}

# %%
sc4a_loss_function_result.append([
     "sc4a-efficientnet-b0-sgd",
     "sc4a", "efficientnet-b0", "sgd", "weighted-CE",
     "validation",
     result["accuracy"],
     result["precision"],
     result["sensitivity"],
     result["specificity"],
     result["f1"],
     result["f2"],
     result["TN"],
     result["FP"],
     result["FN"],
     result["TP"],
])

# %% [markdown]
# ### 4\.2\.5\. Test Data Performance

# %%
# Evaluation for Test data
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=0.5)
result
# Out:
# test evaluation:
# {'accuracy': 0.5263157894736842,
#  'precision': 0.46153846153846156,
#  'sensitivity': 0.75,
#  'specificity': 0.36363636363636365,
#  'f1': 0.5714285714285714,
#  'f2': 0.6666666666666666,
#  'balanced_accuracy': 0.5568181818181819,
#  'TN': 4,
#  'FP': 7,
#  'FN': 2,
#  'TP': 6}

# %%
sc4a_loss_function_result.append([
     "sc4a-efficientnet-b0-sgd",
     "sc4a", "efficientnet-b0", "sgd", "weighted-CE",
     "test",
     result["accuracy"],
     result["precision"],
     result["sensitivity"],
     result["specificity"],
     result["f1"],
     result["f2"],
     result["TN"],
     result["FP"],
     result["FN"],
     result["TP"],
])

# %% [markdown]
# ### 4\.2\.6\. Static Threshold

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=0.5, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 52.87,
#  'accuracy_std. dev': 11.49,
#  'accuracy_ci_low': 31.58,
#  'accuracy_ci_high': 73.68,
#  'precision_mean': 46.48,
#  'precision_std. dev': 14.21,
#  'precision_ci_low': 20.0,
#  'precision_ci_high': 75.0,
#  'sensitivity_mean': 75.37,
#  'sensitivity_std. dev': 15.75,
#  'sensitivity_ci_low': 40.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 36.48,
#  'specificity_std. dev': 14.87,
#  'specificity_ci_low': 9.09,
#  'specificity_ci_high': 66.67,
#  'f1_mean': 56.28,
#  'f1_std. dev': 13.32,
#  'f1_ci_low': 26.67,
#  'f1_ci_high': 80.0,
#  'f2_mean': 65.72,
#  'f2_std. dev': 13.37,
#  'f2_ci_low': 34.87,
#  'f2_ci_high': 87.5,
#  'balanced_accuracy_mean': 55.93,
#  'balanced_accuracy_std. dev': 10.76,
#  'balanced_accuracy_ci_low': 34.09,
#  'balanced_accuracy_ci_high': 76.2}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Weighted CE", "0.5", 0.5,
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.2\.7\. Tuned Threshold

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

raw_curve, raw_thr = threshold_sweep(val_predict, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID,
                                     objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {raw_thr:0.4f}")
display(raw_curve[:5])
# Out:
# Best Threshold on Validation: 0.0750
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
# Evaluation Example
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=raw_thr)
display(raw_thr)
display(result)
# Out:
# test evaluation:
# 0.075
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=raw_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Weighted CE", "tuned", np.round(raw_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.2\.8\. Calibrated Tuned Threshold

# %%
# Temperature scaling on validation logits -> calibrated probs
temperature = fit_temperature(
    val_predict[["logit0", "logit1"]].to_numpy(dtype=np.float32),
    val_predict["label"].to_numpy(dtype=np.int64),
    max_iter=50,
    )

print('temperature:', temperature)

val_pred_cal = apply_temperature(val_predict, temperature)
val_pred_cal.head(5)
# Out:
# temperature: 105.60297393798828
#   child_id                                               path  label  \
# 0        4  /content/drive/MyDrive/Stunted Children Identi...      1
# 1       13  /content/drive/MyDrive/Stunted Children Identi...      0
# 2       24  /content/drive/MyDrive/Stunted Children Identi...      0
# 3       28  /content/drive/MyDrive/Stunted Children Identi...      0
# 4       37  /content/drive/MyDrive/Stunted Children Identi...      0
#
#      logit0    logit1     prob0     prob1  prob1_cal
# 0  0.571267 -0.583350  0.760353  0.239647   0.497267
# 1  1.244774 -1.333962  0.929480  0.070520   0.493896
# 2  0.390364 -0.187113  0.640487  0.359513   0.498633
# 3 -0.413483  0.762882  0.235706  0.764294   0.502785
# 4  0.289673 -0.450173  0.676962  0.323038   0.498249

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

cal_curve, cal_thr = threshold_sweep(val_pred_cal, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID, objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {cal_thr:0.4f}")
display(cal_curve[:5])
# Out:
# Best Threshold on Validation: 0.0750
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
print('test evaluation:')
# Evaluation Example
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=cal_thr)
display(result)
# Out:
# test evaluation:
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=cal_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Weighted CE", "cal. tuned", np.round(cal_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ## 4\.3\. Focal Loss Function

# %% [markdown]
# ### 4\.3\.1\. Model Initialization

# %%
# Model Initialization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Random Configuration
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = create_model(num_classes=2).to(device)
# Out:
# Device: cuda

# %% [markdown]
# ### 4\.3\.2\. Data Loader

# %%
# Load Dataset
dl_val_sc4a   = make_loader(val_sc4a_df, eval_tfms, shuffle=False)
dl_test_sc4a  = make_loader(test_sc4a_df, eval_tfms, shuffle=False)

print(f"\nval={len(val_sc4a_df)} | test={len(test_sc4a_df)}")
# Out:
# val=19 | test=19

# %% [markdown]
# ### 4\.3\.3\. Model Evaluation

# %%
# Prediction on validation and test data
base = "/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/model/"
BEST_PATH = base + "best_model_efficientnet_b0_sc4a_sgd_focal.pth"

model.load_state_dict(torch.load(BEST_PATH, map_location=device))

val_predict   = collect_predictions(model, dl_val_sc4a)
test_predict  = collect_predictions(model, dl_test_sc4a)

# %% [markdown]
# ### 4\.3\.4\. Validation Data Performance

# %%
# Evaluation for Validation data
print('validation evaluation:')
result = metric_bundle(val_predict.label, val_predict.prob1, threshold=0.5)
result
# Out:
# validation evaluation:
# {'accuracy': 0.42105263157894735,
#  'precision': 0.3333333333333333,
#  'sensitivity': 0.375,
#  'specificity': 0.45454545454545453,
#  'f1': 0.35294117647058826,
#  'f2': 0.36585365853658536,
#  'balanced_accuracy': 0.4147727272727273,
#  'TN': 5,
#  'FP': 6,
#  'FN': 5,
#  'TP': 3}

# %%
sc4a_loss_function_result.append([
    "sc4a-efficientnet-b0-sgd",
    "sc4a", "efficientnet-b0", "sgd", "focal",
    "validation",
    result["accuracy"],
    result["precision"],
    result["sensitivity"],
    result["specificity"],
    result["f1"],
    result["f2"],
    result["TN"],
    result["FP"],
    result["FN"],
    result["TP"],
])

# %% [markdown]
# ### 4\.3\.5\. Test Data Performance

# %%
# Evaluation for Test data
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=0.5)
result
# Out:
# test evaluation:
# {'accuracy': 0.47368421052631576,
#  'precision': 0.42857142857142855,
#  'sensitivity': 0.75,
#  'specificity': 0.2727272727272727,
#  'f1': 0.5454545454545454,
#  'f2': 0.6521739130434783,
#  'balanced_accuracy': 0.5113636363636364,
#  'TN': 3,
#  'FP': 8,
#  'FN': 2,
#  'TP': 6}

# %%
sc4a_loss_function_result.append([
     "sc4a-efficientnet-b0-sgd",
     "sc4a", "efficientnet-b0", "sgd", "focal",
     "test",
     result["accuracy"],
     result["precision"],
     result["sensitivity"],
     result["specificity"],
     result["f1"],
     result["f2"],
     result["TN"],
     result["FP"],
     result["FN"],
     result["TP"],
])

# %% [markdown]
# ### 4\.3\.6\. Static Threshold

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=0.5, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 47.54,
#  'accuracy_std. dev': 11.38,
#  'accuracy_ci_low': 26.32,
#  'accuracy_ci_high': 68.42,
#  'precision_mean': 43.1,
#  'precision_std. dev': 13.42,
#  'precision_ci_low': 18.18,
#  'precision_ci_high': 70.0,
#  'sensitivity_mean': 75.37,
#  'sensitivity_std. dev': 15.75,
#  'sensitivity_ci_low': 40.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 27.17,
#  'specificity_std. dev': 13.55,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 55.56,
#  'f1_mean': 53.68,
#  'f1_std. dev': 13.1,
#  'f1_ci_low': 25.0,
#  'f1_ci_high': 76.92,
#  'f2_mean': 64.21,
#  'f2_std. dev': 13.28,
#  'f2_ci_low': 33.33,
#  'f2_ci_high': 85.37,
#  'balanced_accuracy_mean': 51.27,
#  'balanced_accuracy_std. dev': 10.28,
#  'balanced_accuracy_ci_low': 31.67,
#  'balanced_accuracy_ci_high': 70.45}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Focal", "0.5", 0.5,
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.3\.7\. Tuned Threshold

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

raw_curve, raw_thr = threshold_sweep(val_predict, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID,
                                     objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {raw_thr:0.4f}")
display(raw_curve[:5])
# Out:
# Best Threshold on Validation: 0.2550
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
# Evaluation Example
print('test evaluation:')
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=raw_thr)
display(raw_thr)
display(result)
# Out:
# test evaluation:
# 0.255
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=raw_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Focal", "tuned", np.round(raw_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# ### 4\.3\.8\. Calibrated Tuned Threshold

# %%
# Temperature scaling on validation logits -> calibrated probs
temperature = fit_temperature(
    val_predict[["logit0", "logit1"]].to_numpy(dtype=np.float32),
    val_predict["label"].to_numpy(dtype=np.int64),
    max_iter=50,
    )

print('temperature:', temperature)

val_pred_cal = apply_temperature(val_predict, temperature)
val_pred_cal.head(5)
# Out:
# temperature: 112.72468566894531
#   child_id                                               path  label  \
# 0        4  /content/drive/MyDrive/Stunted Children Identi...      1
# 1       13  /content/drive/MyDrive/Stunted Children Identi...      0
# 2       24  /content/drive/MyDrive/Stunted Children Identi...      0
# 3       28  /content/drive/MyDrive/Stunted Children Identi...      0
# 4       37  /content/drive/MyDrive/Stunted Children Identi...      0
#
#      logit0    logit1     prob0     prob1  prob1_cal
# 0  0.197636 -0.148871  0.585770  0.414230   0.499232
# 1  0.497914 -0.595029  0.748936  0.251064   0.497576
# 2  0.250680 -0.015997  0.566277  0.433723   0.499409
# 3 -0.059785  0.359482  0.396692  0.603308   0.500930
# 4  0.027482 -0.158525  0.546368  0.453632   0.499587

# %%
# Raw subject-level probabilities

THRESHOLD_GRID = np.round(np.linspace(0.05, 0.95, 181), 3)
THRESHOLD_OBJECTIVE = "f2"

cal_curve, cal_thr = threshold_sweep(val_pred_cal, prob_col="prob1",
                                     thresholds=THRESHOLD_GRID, objective=THRESHOLD_OBJECTIVE)

print(f"Best Threshold on Validation: {cal_thr:0.4f}")
display(cal_curve[:5])
# Out:
# Best Threshold on Validation: 0.2550
#    threshold  accuracy  precision  sensitivity  specificity        f1  \
# 0      0.050  0.421053   0.421053          1.0          0.0  0.592593
# 1      0.055  0.421053   0.421053          1.0          0.0  0.592593
# 2      0.060  0.421053   0.421053          1.0          0.0  0.592593
# 3      0.065  0.421053   0.421053          1.0          0.0  0.592593
# 4      0.070  0.421053   0.421053          1.0          0.0  0.592593
#
#          f2  balanced_accuracy  TN  FP  FN  TP
# 0  0.784314                0.5   0  11   0   8
# 1  0.784314                0.5   0  11   0   8
# 2  0.784314                0.5   0  11   0   8
# 3  0.784314                0.5   0  11   0   8
# 4  0.784314                0.5   0  11   0   8

# %%
print('test evaluation:')
# Evaluation Example
result = metric_bundle(test_predict.label, test_predict.prob1, threshold=cal_thr)
display(result)
# Out:
# test evaluation:
# {'accuracy': 0.42105263157894735,
#  'precision': 0.42105263157894735,
#  'sensitivity': 1.0,
#  'specificity': 0.0,
#  'f1': 0.5925925925925926,
#  'f2': 0.7843137254901961,
#  'balanced_accuracy': 0.5,
#  'TN': 0,
#  'FP': 11,
#  'FN': 0,
#  'TP': 8}

# %%
# Confidence Interval Example
CI = bootstrap_subject_ci(subject_df=test_predict, prob_col="prob1", threshold=cal_thr, n_boot=2000, seed=SEED)
display(CI)
# Out:
# {'accuracy_mean': 42.27,
#  'accuracy_std. dev': 11.42,
#  'accuracy_ci_low': 21.05,
#  'accuracy_ci_high': 63.16,
#  'precision_mean': 42.27,
#  'precision_std. dev': 11.42,
#  'precision_ci_low': 21.05,
#  'precision_ci_high': 63.16,
#  'sensitivity_mean': 100.0,
#  'sensitivity_std. dev': 0.0,
#  'sensitivity_ci_low': 100.0,
#  'sensitivity_ci_high': 100.0,
#  'specificity_mean': 0.0,
#  'specificity_std. dev': 0.0,
#  'specificity_ci_low': 0.0,
#  'specificity_ci_high': 0.0,
#  'f1_mean': 58.5,
#  'f1_std. dev': 11.48,
#  'f1_ci_low': 34.78,
#  'f1_ci_high': 77.42,
#  'f2_mean': 77.11,
#  'f2_std. dev': 8.73,
#  'f2_ci_low': 57.14,
#  'f2_ci_high': 89.55,
#  'balanced_accuracy_mean': 50.0,
#  'balanced_accuracy_std. dev': 0.0,
#  'balanced_accuracy_ci_low': 50.0,
#  'balanced_accuracy_ci_high': 50.0}

# %%
sc4a_reliability_result.append([
     "EfficientNet-B0", "Focal", "cal. tuned", np.round(cal_thr, 3),
     CI["accuracy_mean"], CI["accuracy_std. dev"],
     CI["sensitivity_mean"], CI["sensitivity_std. dev"],
     CI["specificity_mean"], CI["specificity_std. dev"],
     CI["f2_mean"], CI["f2_std. dev"],
     CI["sensitivity_ci_low"], CI["sensitivity_ci_high"],
     CI["specificity_ci_low"], CI["specificity_ci_high"],
     CI["f2_ci_low"], CI["f2_ci_high"],
])

# %% [markdown]
# # 5\. Result

# %%
sc4a_reliability_result_df = pd.DataFrame(sc4a_reliability_result,
                                          columns=['model', 'loss',
                                                   'dec.', 'tr.',
                                                   'acc-mean','acc-dev',
                                                   'sens-mean','sens-dev',
                                                   'spec-mean','spec-dev',
                                                   'f2-mean','f2-dev',
                                                   'sens-low','sens-high',
                                                   'spec-low','spec-high',
                                                   'f2-low','f2-high',
                                                   ])
display(sc4a_reliability_result_df)

base = "/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/result/"
sc4a_reliability_result_df.to_excel(base + 'sc4a_reliability_result_df.xlsx', index=False)
# Out:
#              model         loss        dec.    tr.  acc-mean  acc-dev  \
# 0  EfficientNet-B0           CE         0.5  0.500     52.28    11.49
# 1  EfficientNet-B0           CE       tuned  0.230     42.27    11.42
# 2  EfficientNet-B0           CE  cal. tuned  0.230     42.27    11.42
# 3  EfficientNet-B0  Weighted CE         0.5  0.500     52.87    11.49
# 4  EfficientNet-B0  Weighted CE       tuned  0.075     42.27    11.42
# 5  EfficientNet-B0  Weighted CE  cal. tuned  0.075     42.27    11.42
# 6  EfficientNet-B0        Focal         0.5  0.500     47.54    11.38
# 7  EfficientNet-B0        Focal       tuned  0.255     42.27    11.42
# 8  EfficientNet-B0        Focal  cal. tuned  0.255     42.27    11.42
#
#    sens-mean  sens-dev  spec-mean  spec-dev  f2-mean  f2-dev  sens-low  \
# 0      24.55     15.65      72.60     13.82    25.84   15.69       0.0
# 1     100.00      0.00       0.00      0.00    77.11    8.73     100.0
# 2     100.00      0.00       0.00      0.00    77.11    8.73     100.0
# 3      75.37     15.75      36.48     14.87    65.72   13.37      40.0
# 4     100.00      0.00       0.00      0.00    77.11    8.73     100.0
# 5     100.00      0.00       0.00      0.00    77.11    8.73     100.0
# 6      75.37     15.75      27.17     13.55    64.21   13.28      40.0
# 7     100.00      0.00       0.00      0.00    77.11    8.73     100.0
# 8     100.00      0.00       0.00      0.00    77.11    8.73     100.0
#
#    sens-high  spec-low  spec-high  f2-low  f2-high
# 0      57.14     42.86     100.00    0.00    57.14
# 1     100.00      0.00       0.00   57.14    89.55
# 2     100.00      0.00       0.00   57.14    89.55
# 3     100.00      9.09      66.67   34.87    87.50
# 4     100.00      0.00       0.00   57.14    89.55
# 5     100.00      0.00       0.00   57.14    89.55
# 6     100.00      0.00      55.56   33.33    85.37
# 7     100.00      0.00       0.00   57.14    89.55
# 8     100.00      0.00       0.00   57.14    89.55

# %%
sc4a_loss_function_result_df = pd.DataFrame(sc4a_loss_function_result,
                                            columns=['model_name',
                                                     'scheme', 'model', 'optimizer', 'loss',
                                                     'evaluation',
                                                     'accuracy',
                                                     'precision',
                                                     'sensitivity',
                                                     'specificity',
                                                     'f1',
                                                     'f2',
                                                     'TN',
                                                     'FP',
                                                     'FN',
                                                     'TP',
                                                     ])
display(sc4a_loss_function_result_df)

base = "/content/drive/MyDrive/Stunted Children Identification/stunting-identification-lab/result/"
sc4a_loss_function_result_df.to_excel(base + 'sc4a_loss_function_result.xlsx', index=False)
# Out:
#                  model_name scheme            model optimizer         loss  \
# 0  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd           CE
# 1  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd           CE
# 2  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd  weighted-CE
# 3  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd  weighted-CE
# 4  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd        focal
# 5  sc4a-efficientnet-b0-sgd   sc4a  efficientnet-b0       sgd        focal
#
#    evaluation  accuracy  precision  sensitivity  specificity        f1  \
# 0  validation  0.473684   0.250000        0.125     0.727273  0.166667
# 1        test  0.526316   0.400000        0.250     0.727273  0.307692
# 2  validation  0.473684   0.333333        0.250     0.636364  0.285714
# 3        test  0.526316   0.461538        0.750     0.363636  0.571429
# 4  validation  0.421053   0.333333        0.375     0.454545  0.352941
# 5        test  0.473684   0.428571        0.750     0.272727  0.545455
#
#          f2  TN  FP  FN  TP
# 0  0.138889   8   3   7   1
# 1  0.270270   8   3   6   2
# 2  0.263158   7   4   6   2
# 3  0.666667   4   7   2   6
# 4  0.365854   5   6   5   3
# 5  0.652174   3   8   2   6
